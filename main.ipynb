# %%
from imagedata_NeoroScan import medical_train, medical_test, display_img
from image_loading import tensorimg, vectorimg, structure_img
print("All Prerequisites Loaded Successfully")
# Out:
# Found 3157
# Successfully loaded 3157
# Found 3453
# Successfully loaded 3453
# Found 711
# Successfully loaded 711
# Found 1424
# Successfully loaded 1424
# Total Training Images: 8745
# All Training Images Loaded Successfully!
# Found 136
# Successfully loaded 136
# Found 140
# Successfully loaded 140
# Found 100
# Successfully loaded 100
# Found 136
# Successfully loaded 136
# Total Training Images: 8745
# All Training Images Loaded Successfully!
# Total Testing Images: 512
# All Testing Images loaded successfully!
# 2.9.1+cpu
# 2.2.4
# 11.1.0
#  13           RESUME                   0
#
#  14           LOAD_GLOBAL              0 (img)
#               LOAD_ATTR                2 (open)
#               PUSH_NULL
#               LOAD_FAST                0 (image_path)
#               CALL                     1
#               STORE_FAST               1 (image)
#
#  15           LOAD_GLOBAL              4 (torch)
#               LOAD_ATTR                6 (from_numpy)
#               PUSH_NULL
#               LOAD_GLOBAL              8 (np)
#               LOAD_ATTR               10 (array)
#               PUSH_NULL
#               LOAD_FAST                1 (image)
#               CALL                     1
#               CALL                     1
#               STORE_FAST               2 (image_tensor)
#
#  17           LOAD_FAST                1 (image)
#               LOAD_ATTR               12 (format)
#
#  18           LOAD_FAST                1 (image)
#               LOAD_ATTR               14 (mode)
#
#  19           LOAD_FAST                1 (image)
#               LOAD_ATTR               16 (size)
#
#  20           LOAD_FAST                2 (image_tensor)
#               LOAD_ATTR               18 (shape)
#
#  21           LOAD_FAST                2 (image_tensor)
#
#  16           LOAD_CONST               1 (('format', 'mode', 'size', 'tensor_shape', 'image_tensor_'))
#               BUILD_CONST_KEY_MAP      5
#               STORE_FAST               3 (metadata)
#
#  23           LOAD_FAST                3 (metadata)
#               RETURN_VALUE
# Image MetaData Function  None
#  29           RESUME                   0
#
#  30           LOAD_GLOBAL              0 (img)
#               LOAD_ATTR                2 (open)
#               PUSH_NULL
#               LOAD_FAST                0 (image_variable)
#               CALL                     1
#               STORE_FAST               1 (image)
#
#  31           LOAD_GLOBAL              4 (torch)
#               LOAD_ATTR                6 (from_numpy)
#               PUSH_NULL
#               LOAD_GLOBAL              8 (np)
#               LOAD_ATTR               10 (array)
#               PUSH_NULL
#               LOAD_FAST                1 (image)
#               CALL                     1
#               CALL                     1
#               STORE_FAST               2 (image_tensor)
#
#  32           LOAD_FAST                2 (image_tensor)
#               RETURN_VALUE
# Tensoring Image Function None
#  36           RESUME                   0
#
#  37           LOAD_CONST               1 ('  ')
#               LOAD_FAST                1 (level)
#               BINARY_OP                5 (*)
#               STORE_FAST               2 (indent)
#
#  38           LOAD_GLOBAL              1 (print + NULL)
#               LOAD_FAST                2 (indent)
#               FORMAT_SIMPLE
#               LOAD_CONST               2 ('Type: ')
#               LOAD_GLOBAL              3 (type + NULL)
#               LOAD_FAST                0 (obj)
#               CALL                     1
#               FORMAT_SIMPLE
#               BUILD_STRING             3
#               CALL                     1
#               POP_TOP
#
#  40           LOAD_GLOBAL              5 (isinstance + NULL)
#               LOAD_FAST                0 (obj)
#               LOAD_GLOBAL              6 (list)
#               LOAD_GLOBAL              8 (tuple)
#               BUILD_TUPLE              2
#               CALL                     2
#               TO_BOOL
#               POP_JUMP_IF_FALSE       59 (to L1)
#               LOAD_GLOBAL             11 (len + NULL)
#               LOAD_FAST                0 (obj)
#               CALL                     1
#               LOAD_CONST               3 (0)
#               COMPARE_OP             148 (bool(>))
#               POP_JUMP_IF_FALSE       44 (to L1)
#
#  41           LOAD_GLOBAL              1 (print + NULL)
#               LOAD_FAST                2 (indent)
#               FORMAT_SIMPLE
#               LOAD_CONST               4 ('Lenght: ')
#               LOAD_GLOBAL             11 (len + NULL)
#               LOAD_FAST                0 (obj)
#               CALL                     1
#               FORMAT_SIMPLE
#               BUILD_STRING             3
#               CALL                     1
#               POP_TOP
#
#  42           LOAD_GLOBAL             13 (structure_img + NULL)
#               LOAD_FAST                0 (obj)
#               LOAD_CONST               3 (0)
#               BINARY_SUBSCR
#               LOAD_FAST                1 (level)
#               LOAD_CONST               5 (1)
#               BINARY_OP                0 (+)
#               CALL                     2
#               POP_TOP
#               RETURN_CONST             0 (None)
#
#  44   L1:     LOAD_GLOBAL              5 (isinstance + NULL)
#               LOAD_FAST                0 (obj)
#               LOAD_GLOBAL             14 (dict)
#               CALL                     2
#               TO_BOOL
#               POP_JUMP_IF_FALSE       63 (to L2)
#
#  45           LOAD_GLOBAL             17 (next + NULL)
#               LOAD_GLOBAL             19 (iter + NULL)
#               LOAD_FAST                0 (obj)
#               CALL                     1
#               CALL                     1
#               STORE_FAST               3 (first_key)
#
#  46           LOAD_GLOBAL              1 (print + NULL)
#               LOAD_FAST                2 (indent)
#               FORMAT_SIMPLE
#               LOAD_CONST               6 ('Key Type: ')
#               LOAD_GLOBAL              3 (type + NULL)
#               LOAD_FAST                3 (first_key)
#               CALL                     1
#               FORMAT_SIMPLE
#               BUILD_STRING             3
#               CALL                     1
#               POP_TOP
#
#  47           LOAD_GLOBAL             13 (structure_img + NULL)
#               LOAD_FAST_LOAD_FAST      3 (obj, first_key)
#               BINARY_SUBSCR
#               LOAD_FAST                1 (level)
#               LOAD_CONST               5 (1)
#               BINARY_OP                0 (+)
#               CALL                     2
#               POP_TOP
#               RETURN_CONST             0 (None)
#
#  44   L2:     RETURN_CONST             0 (None)
# Structuring Image function = None
#   52           RESUME                   0
#
#   53           BUILD_LIST               0
#                STORE_FAST               1 (vectors)
#
#   55           LOAD_GLOBAL              0 (transforms)
#                LOAD_ATTR                2 (Compose)
#                PUSH_NULL
#
#   56           LOAD_GLOBAL              0 (transforms)
#                LOAD_ATTR                4 (Resize)
#                PUSH_NULL
#                LOAD_CONST               1 ((128, 128))
#                CALL                     1
#
#   57           LOAD_FAST_CHECK          2 (transform)
#                LOAD_ATTR                7 (ToTensor + NULL|self)
#                CALL                     0
#
#   55           BUILD_LIST               2
#                CALL                     1
#                STORE_FAST               2 (transform)
#
#   61           LOAD_FAST                0 (image_list)
#                GET_ITER
#                FOR_ITER               164 (to L7)
#                STORE_FAST               3 (_img_)
#
#   63           LOAD_GLOBAL              8 (img)
#                LOAD_ATTR               10 (open)
#                PUSH_NULL
#                LOAD_FAST                3 (_img_)
#                CALL                     1
#                LOAD_ATTR               13 (convert + NULL|self)
#                LOAD_CONST               2 ('RGB')
#                CALL                     1
#                STORE_FAST               3 (_img_)
#
#   64           LOAD_GLOBAL             14 (torch)
#                LOAD_ATTR               16 (from_numpy)
#                PUSH_NULL
#                LOAD_GLOBAL             18 (np)
#                LOAD_ATTR               20 (array)
#                PUSH_NULL
#                LOAD_FAST                3 (_img_)
#                CALL                     1
#                CALL                     1
#                STORE_FAST               4 (tensor_img)
#
#   65           LOAD_FAST                1 (vectors)
#                LOAD_ATTR               23 (append + NULL|self)
#                LOAD_FAST                4 (tensor_img)
#                CALL                     1
#                POP_TOP
#
#   67           LOAD_FAST                1 (vectors)
#                GET_ITER
#        L1:     FOR_ITER                57 (to L6)
#                STORE_FAST               5 (i)
#
#   68           LOAD_FAST                1 (vectors)
#                GET_ITER
#                LOAD_FAST_AND_CLEAR      5 (i)
#                SWAP                     2
#        L2:     BUILD_LIST               0
#                SWAP                     2
#                GET_ITER
#        L3:     FOR_ITER                19 (to L4)
#                STORE_FAST_LOAD_FAST    85 (i, i)
#                LOAD_ATTR               25 (view + NULL|self)
#                LOAD_CONST               3 (-1)
#                CALL                     1
#                LIST_APPEND              2
#                JUMP_BACKWARD           21 (to L3)
#        L4:     END_FOR
#                POP_TOP
#        L5:     STORE_FAST               1 (vectors)
#                STORE_FAST               5 (i)
#
#   69           LOAD_GLOBAL             14 (torch)
#                LOAD_ATTR               26 (stack)
#                PUSH_NULL
#                LOAD_FAST                1 (vectors)
#                CALL                     1
#                STORE_FAST               6 (vector_tensor)
#                JUMP_BACKWARD           59 (to L1)
#
#   67   L6:     END_FOR
#                POP_TOP
#
#   71           LOAD_FAST_CHECK          6 (vector_tensor)
#                SWAP                     2
#                POP_TOP
#                RETURN_VALUE
#
#   61   L7:     END_FOR
#                POP_TOP
#                RETURN_CONST             0 (None)
#
#   --   L8:     SWAP                     2
#                POP_TOP
#
#   68           SWAP                     2
#                STORE_FAST               5 (i)
#                RERAISE                  0
# ExceptionTable:
#   L2 to L5 -> L8 [4]
# Vectorizing Image Function = None
# All Prerequisites Loaded Successfully

# %%
print("Training Images...")
train_image = display_img(medical_train, 0, 15)
# Out:
# Training Images...

# %%
print("Testing Images...")
test_image = display_img(medical_test, 0, 15)
# Out:
# Testing Images...

# %%
print("Medical Training Sets =",len(medical_train))
print("Medical Testing Sets =",len(medical_test))
# Out:
# Medical Training Sets = 4
# Medical Testing Sets = 4

# %%
print("Structure of Training Images :")
str_training = structure_img(medical_train)
# Out:
# Structure of Training Images :
# Type: <class 'list'>
# Lenght: 4
#   Type: <class 'list'>
#   Lenght: 3157
#     Type: <class 'PIL.Image.Image'>

# %%
print("Structure of Testing Images :")
str_testing = structure_img(medical_test)
# Out:
# Structure of Testing Images :
# Type: <class 'list'>
# Lenght: 4
#   Type: <class 'list'>
#   Lenght: 136
#     Type: <class 'PIL.Image.Image'>
